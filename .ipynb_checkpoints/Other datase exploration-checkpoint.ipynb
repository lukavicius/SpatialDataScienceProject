# %% [markdown]
# # Human Development Index (HDI) Dataset by the UN
# This I think is a pretty full dataset by the UN on Human Development Index. More about it you can find here: https://hdr.undp.org/data-center/human-development-index#/indicies/HDI. \
# I have also included in the repository the metadata file (HDR25_Composite_indices_metadata), in which you can find all the indicators and identifiers.\
# There are pretty interesting indicators, which for Gender Inequality they have a specific category, with these indicators:\
# GII Rank	gii_rank\
# Gender Inequality Index (value)	gii\
# Maternal Mortality Ratio (deaths per 100,000 live births)	mmr\
# Adolescent Birth Rate (births per 1,000 women ages 15-19)	abr\
# Population with at least some secondary education, female (% ages 25 and older)	se_f\
# Population with at least some secondary education, male (% ages 25 and older)	se_m\
# Share of seats in parliament, female (% held by women)	pr_f\
# Share of seats in parliament, male (% held by men)	pr_m\
# Labour force participation rate, female (% ages 15 and older)	lfpr_f\
# Labour force participation rate, male (% ages 15 and older)	lfpr_m\
# The letters are an id for the data queries.

# %%
import pandas as pd

class HDIData:
    def __init__(self, filepath: str):
        """
        Initialize the HDIData object by loading a CSV file into a DataFrame.
        """
        # Read CSV safely
        self.df = pd.read_csv(filepath, encoding="ISO-8859-1")
        
        # Standardize column names
        self.df.columns = self.df.columns.str.strip().str.lower().str.replace(' ', '_')
        
        # Convert wide-format year columns into long format
        self.long_df = self._reshape_long(self.df)
    
    def _reshape_long(self, df):
        """
        Converts wide-format year columns into long format for easier filtering.
        """
        id_vars = ['iso3', 'country', 'region']  # columns to keep
        value_vars = [col for col in df.columns if any(col.startswith(prefix) for prefix in ['hdi_', 'le_', 'eys_', 'mys_', 'gnipc_', 'gdi_', 'gii_', 'co2_prod_'])]
        
        # Melt the wide columns into long format
        long_df = df.melt(id_vars=id_vars, value_vars=value_vars, var_name='metric_year', value_name='value')
        
        # Split 'metric_year' into 'metric' and 'year'
        long_df[['metric', 'year']] = long_df['metric_year'].str.rsplit('_', n=1, expand=True)
        long_df['year'] = long_df['year'].astype(int)
        long_df.drop(columns='metric_year', inplace=True)
        
        return long_df

    def get_data(self, countries=None, years=None, metric=None):
        """
        Retrieve data for a given metric, list of countries, and/or years.
        """
        df = self.long_df.copy()
        
        # Filter by countries
        if countries is not None:
            if isinstance(countries, str):
                countries = [countries]
            df = df[df['country'].str.lower().isin([c.lower() for c in countries])]
        
        # Filter by years
        if years is not None:
            if isinstance(years, tuple):  # range
                df = df[(df['year'] >= years[0]) & (df['year'] <= years[1])]
            elif isinstance(years, list):
                df = df[df['year'].isin(years)]
            else:  # single year
                df = df[df['year'] == years]
        
        # Filter by metric
        if metric is not None:
            metric = metric.lower().replace(' ', '_')
            df = df[df['metric'] == metric]
        
        return df.reset_index(drop=True)

# %%
# Load CSV
hdi = HDIData("HDR25_Composite_indices_complete_time_series.csv")

# Get HDI for Norway, 2010-2020
norway_hdi = hdi.get_data(countries="Norway", years=(2010, 2020), metric="HDI")

# Life expectancy for Japan and Sweden in 2020
life_exp = hdi.get_data(countries=["Nicaragua", "Sweden"], years=(2000, 2020), metric="gii")

# %%
print(life_exp)
# Out:
#    iso3    country region  value metric  year
# 0   NIC  Nicaragua    LAC  0.569    gii  2000
# 1   SWE     Sweden    NaN  0.059    gii  2000
# 2   NIC  Nicaragua    LAC  0.573    gii  2001
# 3   SWE     Sweden    NaN  0.056    gii  2001
# 4   NIC  Nicaragua    LAC  0.526    gii  2002
# 5   SWE     Sweden    NaN  0.053    gii  2002
# 6   NIC  Nicaragua    LAC  0.521    gii  2003
# 7   SWE     Sweden    NaN  0.048    gii  2003
# 8   NIC  Nicaragua    LAC  0.524    gii  2004
# 9   SWE     Sweden    NaN  0.047    gii  2004
# 10  NIC  Nicaragua    LAC  0.521    gii  2005
# 11  SWE     Sweden    NaN  0.047    gii  2005
# 12  NIC  Nicaragua    LAC  0.528    gii  2006
# 13  SWE     Sweden    NaN  0.046    gii  2006
# 14  NIC  Nicaragua    LAC  0.515    gii  2007
# 15  SWE     Sweden    NaN  0.046    gii  2007
# 16  NIC  Nicaragua    LAC  0.506    gii  2008
# 17  SWE     Sweden    NaN  0.048    gii  2008
# 18  NIC  Nicaragua    LAC  0.488    gii  2009
# 19  SWE     Sweden    NaN  0.049    gii  2009
# 20  NIC  Nicaragua    LAC  0.478    gii  2010
# 21  SWE     Sweden    NaN  0.050    gii  2010
# 22  NIC  Nicaragua    LAC  0.434    gii  2011
# 23  SWE     Sweden    NaN  0.050    gii  2011
# 24  NIC  Nicaragua    LAC  0.426    gii  2012
# 25  SWE     Sweden    NaN  0.047    gii  2012
# 26  NIC  Nicaragua    LAC  0.425    gii  2013
# 27  SWE     Sweden    NaN  0.045    gii  2013
# 28  NIC  Nicaragua    LAC  0.431    gii  2014
# 29  SWE     Sweden    NaN  0.042    gii  2014
# 30  NIC  Nicaragua    LAC  0.431    gii  2015
# 31  SWE     Sweden    NaN  0.038    gii  2015
# 32  NIC  Nicaragua    LAC  0.424    gii  2016
# 33  SWE     Sweden    NaN  0.036    gii  2016
# 34  NIC  Nicaragua    LAC  0.424    gii  2017
# 35  SWE     Sweden    NaN  0.034    gii  2017
# 36  NIC  Nicaragua    LAC  0.423    gii  2018
# 37  SWE     Sweden    NaN  0.029    gii  2018
# 38  NIC  Nicaragua    LAC  0.421    gii  2019
# 39  SWE     Sweden    NaN  0.022    gii  2019
# 40  NIC  Nicaragua    LAC  0.418    gii  2020
# 41  SWE     Sweden    NaN  0.017    gii  2020

# %% [markdown]
# # Environmental Performance Index (EPI) - Yale
# First, a quick look through the metadata file, basically all the indicators. You can also instead look at the epi2024variables2024-12-11.csv file. A nicer description of it is on the website, however, for indicator IDs its easier to use this me thinks.
# Website: https://epi.yale.edu/

# %%
import pandas as pd

class IndicatorCSVReader:
    def __init__(self, filepath: str):
        """
        Initialize the reader for indicator metadata CSV files.
        
        Parameters:
        -----------
        filepath : str
            Path to the CSV file.
        encoding : str
            File encoding (default: ISO-8859-1)
        """
        # Read CSV safely
        self.df = pd.read_csv(filepath)
        
        # Standardize column names
        self.df.columns = self.df.columns.str.strip().str.lower().str.replace(' ', '_')

    def get_data(self, types=None, variables=None, categories=None):
        """
        Filter indicator metadata by type, variable, or category.
        
        Parameters:
        -----------
        types : str | list[str] | None
            Filter by Type column.
        variables : str | list[str] | None
            Filter by Variable column.
        categories : str | list[str] | None
            Filter by IssueCategory or PolicyObjective.
            
        Returns:
        --------
        pd.DataFrame
            Filtered metadata.
        """
        df = self.df.copy()
        
        # Filter by Type
        if types is not None:
            if isinstance(types, str):
                types = [types]
            df = df[df['type'].str.lower().isin([t.lower() for t in types])]
        
        # Filter by Variable
        if variables is not None:
            if isinstance(variables, str):
                variables = [variables]
            df = df[df['variable'].str.lower().isin([v.lower() for v in variables])]
        
        # Filter by IssueCategory or PolicyObjective
        if categories is not None:
            if isinstance(categories, str):
                categories = [categories]
            df = df[
                df['issuecategory'].str.lower().isin([c.lower() for c in categories]) |
                df['policyobjective'].str.lower().isin([c.lower() for c in categories])
            ]
        
        return df.reset_index(drop=True)

# %%
reader = IndicatorCSVReader('epi2024variables2024-12-11.csv')

# Get only EPI rows
df_epi = reader.get_data()
print(df_epi)

# Get all indicators under "Ecosystem Vitality"
df_eco = reader.get_data(categories='Ecosystem Vitality')
print(df_eco)

# Get a specific variable
df_bdh = reader.get_data(variables='BDH')
print(df_bdh)
# Out:
#                type abbreviation  \
# 0               EPI          EPI
# 1   PolicyObjective          ECO
# 2     IssueCategory          BDH
# 3         Indicator          MKP
# 4         Indicator          MHP
# ..              ...          ...
# 68        Indicator          LUF
# 69        Indicator          GTI
# 70        Indicator          GTP
# 71        Indicator          GHN
# 72        Indicator          CBP
#
#                                              variable  \
# 0                     Environmental Performance Index
# 1                                  Ecosystem Vitality
# 2                              Biodiversity & Habitat
# 3                               Marine KBA Protection
# 4                           Marine Habitat Protection
# ..                                                ...
# 68         Net carbon fluxes due to land cover change
# 69    GHG growth rate adjusted by emissions intensity
# 70   GHG growth rate adjusted by per capita emissions
# 71                        Projected emissions in 2050
# 72  Projected cumulative emissions to 2050 relativ...
#
#                 issuecategory     policyobjective  weight  \
# 0                         NaN                 NaN     NaN
# 1                         NaN                 NaN  45.00%
# 2                         NaN  Ecosystem Vitality  25.00%
# 3      Biodiversity & Habitat  Ecosystem Vitality   3.00%
# 4      Biodiversity & Habitat  Ecosystem Vitality   3.00%
# ..                        ...                 ...     ...
# 68  Climate Change Mitigation     Climate Change    1.00%
# 69  Climate Change Mitigation     Climate Change    6.00%
# 70  Climate Change Mitigation     Climate Change    6.00%
# 71  Climate Change Mitigation     Climate Change    1.00%
# 72  Climate Change Mitigation     Climate Change    0.50%
#
#                                           description
# 0   The 2024 EPI combines 58 indicators across 11 ...
# 1   The Ecosystem Vitality policy objective measur...
# 2   The Biodiversity and Habitat issue category as...
# 3   Percentage of area designated as Key Biodivers...
# 4   Percentage of important marine and coastal hab...
# ..                                                ...
# 68  The sum of carbon fluxes (both emissions and s...
# 69  Average annual growth rate in greenhouse gas e...
# 70  Average annual growth rate in greenhouse gas e...
# 71  The projected emissions levels in 2050 indicat...
# 72  This pilot indicator of projected cumulative e...
#
# [73 rows x 7 columns]
#              type abbreviation  \
# 0   IssueCategory          BDH
# 1       Indicator          MKP
# 2       Indicator          MHP
# 3       Indicator          MPE
# 4       Indicator          PAR
# 5       Indicator          SPI
# 6       Indicator          TBN
# 7       Indicator          TKP
# 8       Indicator          PAE
# 9       Indicator          PHL
# 10      Indicator          RLI
# 11      Indicator          SHI
# 12      Indicator          BER
# 13  IssueCategory          ECS
# 14      Indicator          PFL
# 15      Indicator          IFL
# 16      Indicator          FCL
# 17      Indicator          TCG
# 18      Indicator          FLI
# 19  IssueCategory          FSH
# 20      Indicator          FSS
# 21      Indicator          FCD
# 22      Indicator          BTZ
# 23      Indicator          BTO
# 24      Indicator          RMS
# 25  IssueCategory          APO
# 26      Indicator          OEB
# 27      Indicator          OEC
# 28      Indicator          NXA
# 29      Indicator          SDA
# 30  IssueCategory          AGR
# 31      Indicator          SNM
# 32      Indicator          PSU
# 33      Indicator          PRS
# 34      Indicator          RCY
# 35  IssueCategory          WRS
# 36      Indicator          WWG
# 37      Indicator          WWC
# 38      Indicator          WWT
# 39      Indicator          WWR
#
#                                              variable           issuecategory  \
# 0                              Biodiversity & Habitat                     NaN
# 1                               Marine KBA Protection  Biodiversity & Habitat
# 2                           Marine Habitat Protection  Biodiversity & Habitat
# 3                        Marine Protection Stringency  Biodiversity & Habitat
# 4            Protected Areas Representativeness Index  Biodiversity & Habitat
# 5                            Species Protection Index  Biodiversity & Habitat
# 6     Terrestrial Biome Protection (national weights)  Biodiversity & Habitat
# 7                          Terrestrial KBA Protection  Biodiversity & Habitat
# 8                        Protected Area Effectiveness  Biodiversity & Habitat
# 9                                Protected Human Land  Biodiversity & Habitat
# 10                                     Red List Index  Biodiversity & Habitat
# 11                              Species Habitat Index  Biodiversity & Habitat
# 12                   Bioclimatic Ecosystem Resilience  Biodiversity & Habitat
# 13                                            Forests                     NaN
# 14                                Primary Forest Loss                 Forests
# 15                       Intact Forest Landscape Loss                 Forests
# 16             Tree cover loss weighted by permanency                 Forests
# 17                           Net change in tree cover                 Forests
# 18                          Forest Lanscape Integrity                 Forests
# 19                                          Fisheries                     NaN
# 20                                  Fish Stock Status               Fisheries
# 21                               Fish Catch Discarded               Fisheries
# 22                             Bottom Trawling in EEZ               Fisheries
# 23                    Bottom Trawling in Global Ocean               Fisheries
# 24                      Regional Marine Trophic Index               Fisheries
# 25                                      Air Pollution                     NaN
# 26                                Ozone exposure KBAs           Air Pollution
# 27                           Ozone exposure croplands           Air Pollution
# 28  Adjusted emissions growth rate for nitrous oxides           Air Pollution
# 29  Adjusted emissions growth rate for sulfur dioxide           Air Pollution
# 30                                        Agriculture                     NaN
# 31              Sustainable Nitrogen Management Index             Agriculture
# 32                                 Phosphorus Surplus             Agriculture
# 33                           Pesticide Pollution Risk             Agriculture
# 34                                Relative Crop Yield             Agriculture
# 35                                    Water Resources                     NaN
# 36                               Wastewater generated         Water Resources
# 37                               Wastewater collected         Water Resources
# 38                                 Wastewater treated         Water Resources
# 39                                  Wastewater reused         Water Resources
#
#        policyobjective  weight  \
# 0   Ecosystem Vitality  25.00%
# 1   Ecosystem Vitality   3.00%
# 2   Ecosystem Vitality   3.00%
# 3   Ecosystem Vitality   0.50%
# 4   Ecosystem Vitality   3.00%
# 5   Ecosystem Vitality   4.00%
# 6   Ecosystem Vitality   2.50%
# 7   Ecosystem Vitality   2.50%
# 8   Ecosystem Vitality   0.50%
# 9   Ecosystem Vitality   0.50%
# 10  Ecosystem Vitality   3.00%
# 11  Ecosystem Vitality   2.00%
# 12  Ecosystem Vitality   0.50%
# 13  Ecosystem Vitality   5.00%
# 14  Ecosystem Vitality   1.50%
# 15  Ecosystem Vitality   1.50%
# 16  Ecosystem Vitality   1.25%
# 17  Ecosystem Vitality   0.50%
# 18  Ecosystem Vitality   0.25%
# 19  Ecosystem Vitality   2.00%
# 20  Ecosystem Vitality   0.30%
# 21  Ecosystem Vitality   0.40%
# 22  Ecosystem Vitality   0.50%
# 23  Ecosystem Vitality   0.70%
# 24  Ecosystem Vitality   0.10%
# 25  Ecosystem Vitality   6.00%
# 26  Ecosystem Vitality   0.50%
# 27  Ecosystem Vitality   0.50%
# 28  Ecosystem Vitality   2.50%
# 29  Ecosystem Vitality   2.50%
# 30  Ecosystem Vitality   3.00%
# 31  Ecosystem Vitality   1.20%
# 32  Ecosystem Vitality   0.10%
# 33  Ecosystem Vitality   0.50%
# 34  Ecosystem Vitality   1.20%
# 35  Ecosystem Vitality   5.00%
# 36  Ecosystem Vitality   0.50%
# 37  Ecosystem Vitality   2.00%
# 38  Ecosystem Vitality   2.00%
# 39  Ecosystem Vitality   0.50%
#
#                                           description
# 0   The Biodiversity and Habitat issue category as...
# 1   Percentage of area designated as Key Biodivers...
# 2   Percentage of important marine and coastal hab...
# 3   This pilot indicator estimates the stringency ...
# 4   The Protected Areas Representativeness Index (...
# 5   The Species Protection Index (SPI) measures ho...
# 6   We derive the terrestrial biome protection ind...
# 7   Percentage of area designated as Key Biodivers...
# 8   This pilot indicator measures the percentage o...
# 9   This pilot indicator measures the percentage o...
# 10  The Red List Index (RLI) tracks the overall ex...
# 11  The Species Habitat Index (SHI) measures the p...
# 12  The Bioclimatic Ecosystem Resilience Index (BE...
# 13  The Forests issue category (previously called ...
# 14  Humid tropical primary forests are the most bi...
# 15  Intact forest landscapes are large and pristin...
# 16  Not all tree cover loss is the same. Depending...
# 17               Forest landscapes are highly dynamic
# 18       Going beyond measuring changes in tree cover
# 19  The Fisheries issue category measures the heal...
# 20  Fish stock status is the percentage of a count...
# 21  The proportion of a country’s total catch in t...
# 22  The proportion of the total catch in a country...
# 23  The proportion of a country’s total catch acro...
# 24  A measurement of how fast the trophic level of...
# 25  The Air Pollution issue category (previously c...
# 26  As a proxy of ozone pollution effects on biodi...
# 27  As a proxy of ozone pollution effects on crop ...
# 28  We measure the average annual rate of nitrogen...
# 29  We measure the average annual rate of sulfur d...
# 30  The Agriculture issue category measures effort...
# 31  The Sustainable Nitrogen Management Index (SNM...
# 32  The difference between phosphorus inputs (as f...
# 33  The risk agricultural pesticide pollution to b...
# 34                The average yield of 17 major crops
# 35  The Water Resources issue category measures th...
# 36  Total amount of municipal wastewater generated...
# 37  Percentage of wastewater collected for treatme...
# 38  Percentage of wastewater that undergoes at lea...
# 39    Percentage of wastewater reused after treatment
# Empty DataFrame
# Columns: [type, abbreviation, variable, issuecategory, policyobjective, weight, description]
# Index: []

# %% [markdown]
# Next, we retrieve a df depending on the country, variable, and years:

# %%
import pandas as pd
import os

def load_indicators(variables, countries=None, years=None, folder_path='P5_Indicator'):
    """
    Load environmental/social indicators from CSV files and filter by country/year.

    Parameters:
    -----------
    variables : str | list[str]
        Variable abbreviations, e.g., 'BCA' or ['BCA', 'BER'].
    countries : str | list[str] | None
        Country or list of countries to filter.
    years : int | list[int] | tuple(int, int) | None
        Single year, list of years, or range (start, end) to filter.
    folder_path : str
        Path to the folder containing CSV files.

    Returns:
    --------
    pd.DataFrame
        Long-format DataFrame with columns: country, iso, variable, year, value
    """
    if isinstance(variables, str):
        variables = [variables]
    
    all_dfs = []

    for var in variables:
        filename = os.path.join(folder_path, f"{var}_ind_na.csv")
        if not os.path.exists(filename):
            raise FileNotFoundError(f"File {filename} not found.")
        
        # Load CSV safely
        df = pd.read_csv(filename)
        
        # Standardize columns
        df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')
        
        # Identify year columns for this variable
        year_cols = [col for col in df.columns if col.startswith(var.lower() + '.ind.')]
        
        # Melt wide -> long
        long_df = df.melt(id_vars=['iso','country'], value_vars=year_cols, 
                          var_name='metric_year', value_name='value')
        
        # Extract year from column name
        long_df['year'] = long_df['metric_year'].str.split('.').str[-1].astype(int)
        long_df['variable'] = var
        long_df = long_df.drop(columns='metric_year')
        
        all_dfs.append(long_df)
    
    # Combine multiple variables
    result = pd.concat(all_dfs, ignore_index=True)
    
    # Filter countries
    if countries is not None:
        if isinstance(countries, str):
            countries = [countries]
        result = result[result['country'].str.lower().isin([c.lower() for c in countries])]
    
    # Filter years
    if years is not None:
        if isinstance(years, tuple):  # range
            result = result[(result['year'] >= years[0]) & (result['year'] <= years[1])]
        elif isinstance(years, list):
            result = result[result['year'].isin(years)]
        else:  # single year
            result = result[result['year'] == years]
    
    return result.reset_index(drop=True)

# %%
# Load BCA indicator for Afghanistan and Albania for 2000-2005
df = load_indicators(variables='BCA', countries=['Afghanistan','Albania'], years=(2000,2005))
print(df.head())

# Load multiple variables for all countries in 2010
df2 = load_indicators(variables=['BCA','BER'], years=2010)
print(df2.head())
# Out:
#    iso      country  value  year variable
# 0  AFG  Afghanistan   42.1  2000      BCA
# 1  ALB      Albania   30.0  2000      BCA
# 2  AFG  Afghanistan   41.9  2001      BCA
# 3  ALB      Albania    0.0  2001      BCA
# 4  AFG  Afghanistan   41.6  2002      BCA
#    iso      country  value  year variable
# 0  AFG  Afghanistan   15.6  2010      BCA
# 1  ALB      Albania   42.3  2010      BCA
# 2  DZA      Algeria   15.0  2010      BCA
# 3  AND      Andorra    NaN  2010      BCA
# 4  AGO       Angola   12.1  2010      BCA
